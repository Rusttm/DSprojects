# %% [markdown]
# #Этапы работы над Data Science проектом:
#
# 1. Постановка задачи: Определение целей проекта, формулировка бизнес-проблемы и ожидаемых результатов.
#
# 2. Сбор данных: Получение необходимых данных из различных источников, таких как базы данных, веб-сервисы, файлы и т.д.
#
# 3. Предобработка и очистка данных: Обработка пропущенных значений, удаление дубликатов, преобразование данных в нужный формат, нормализация и масштабирование.
#
# 4. Исследовательский анализ данных (EDA): Изучение структуры и особенностей данных, поиск закономерностей, аномалий и взаимосвязей с помощью статистических методов и визуализации.
#
# 5. Построение и выбор модели: Разделение данных на обучающую и тестовую выборки, создание и обучение различных моделей машинного обучения, оценка их качества и выбор лучшей модели.
#
# 6. Оценка и интерпретация результатов: Проверка качества модели на тестовой выборке, интерпретация полученных результатов и их значимости для бизнес-задачи.
#
# 7. Развертывание и внедрение: Подготовка модели к использованию в реальных условиях, создание пользовательского интерфейса или интеграция с существующими системами.
#
# 8. Мониторинг и обновление: Отслеживание производительности модели с течением времени, обновление модели при необходимости с учетом новых данных и изменений в бизнес-требованиях.

# %% [markdown]
# #**Первичный и визуальный анализ данных (EDA - Exploratory Data Analysis)**

# %% [markdown]
# является важным этапом в процессе работы над проектом по Data Science. Он помогает исследователю лучше понять структуру и особенности данных, с которыми предстоит работать. Этот этап включает в себя следующие шаги:
#
# 1. Изучение структуры данных: Определение типов переменных (количественные, категориальные), проверка наличия пропущенных значений, изучение размерности данных.
#
# 2. Анализ распределений: Исследование распределения значений для каждой переменной с помощью гистограмм, box plot и других графиков. Выявление выбросов и аномалий.
#
# 3. Анализ взаимосвязей: Изучение взаимосвязей между переменными с использованием диаграмм рассеяния (scatter plot), матриц корреляций и других методов визуализации.
#
# 4. Выявление закономерностей и особенностей: Поиск интересных паттернов, трендов и закономерностей в данных, которые могут быть полезны для дальнейшего анализа и моделирования.
#
# 5. Формулировка гипотез: На основе полученных наблюдений формулируются предположения и гипотезы о природе данных и взаимосвязях между переменными.
#
# Первичный и визуальный анализ данных является итеративным процессом, в ходе которого исследователь может возвращаться к предыдущим шагам по мере обнаружения новых особенностей или возникновения новых вопросов.

# %% [markdown]
# Изучение данных о сердце с помощью набора данных "heart.csv"
# **Вступление:**
# В этом блокноте мы намерены проанализировать данные, относящиеся к кардиологическим особенностям пациентов, из набора данных "heart.csv". Этот набор данных предоставляет различную информацию о пациентах, включая возраст, пол, кровяное давление, уровень холестерина, электрокардиографические характеристики (ЭКГ) и многое другое.
#
# Информация о наборе данных:
# Этот набор данных включает следующие характеристики:
#
# `age`: Возраст пациента
# `sex`: Пол пациента (0: женщина, 1: мужчина).
# `cp`: Тип боли в груди.
#     *0*: Типичная стенокардия
#     *1*: Атипичная стенокардия
#     *2*: Боль, не связанная со стенокардией
#     *3*: Бессимптомная
# `trestbps`: Артериальное давление в состоянии покоя.
# `slope`: Наклон верхней части первого сегмента упражнения:
#     0: Подъем
#     1: Пологий
#     2: Спуск
# `chol`: холестерин в сыворотке крови.
# `ca` : Количество крупных сосудов (0-4), окрашенных при рентгеноскопии
# `fbs`: Уровень сахара в крови натощак > 120 мг/дл.
# `restecg`: Результаты электрокардиографии в состоянии покоя.
# `thal`: Результат нагрузочного теста на таллий:
#     0: В норме
#     1: Исправленный дефект
#     2: Обратимый дефект
#     3: Не описано
# `thalach`: Достигнута максимальная частота сердечных сокращений.
# `exang`: Стенокардия, вызванная физической нагрузкой.
#     (1 = yes, 0 = no)
# `oldpeak`: снижение уровня ST, вызванное физической нагрузкой по сравнению с отдыхом.
# `target`: Статус сердечно-сосудистых заболеваний (0 = отсутствие заболевания, 1 = наличие заболевания)

# %% [markdown]
# ## Задание № 1

# %% [markdown]
# Анализ данных о сердечных заболеваниях (Heart Disease Dataset):
#    - Загрузите датасет Heart Disease
#    - Проведите первичный анализ данных: изучите типы переменных, наличие пропусков, статистические характеристики.

# %% [markdown]
# ### Загрузка библиотек

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import ListedColormap

# %% [markdown]
# ###Первичный анализ

# %%
df_heart = pd.read_csv('heart.csv')
df_heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df_heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# 1. Данные состоят из 303 наблюдений (строк) и 14 переменных (столбцов).
# 2. Все переменные, кроме 'oldpeak', имеют целочисленный тип данных (int64), что указывает на то, что они могут представлять собой категориальные или дискретные значения.
# 3. Переменная 'oldpeak' имеет тип float64, что означает, что она содержит непрерывные числовые значения.
# 4. Нет пропущенных значений в данных, так как для каждой переменной количество non-null значений равно общему количеству наблюдений (303).
# 5. Переменная 'target' является целевой переменной (зависимой переменной), которую нужно предсказывать или анализировать в зависимости от других переменных.
# 6. Переменные 'cp', 'restecg', 'slope', 'ca' и 'thal' представляют собой категориальные переменные, так как имеют целочисленный тип данных.

# %% [markdown]
# ###Статистические характеристики признаков

# %% [markdown]
# Для анализа и интерпретации необходимо преобразовать 9 столбцов (cp, fbs, restecg, slope, sex, ca, thal, exang и target) из числовых в строковый тип данных, несмотря на их числовую природу. Такой вывод основан на рассмотрении типов данных и объяснений функций, представленных ранее.

# %%
# Определим непрерывные признаки
continuous_features = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# Определим признаки, которые будут преобразованы в объектный тип данных
features_to_convert = [feature for feature in df_heart.columns if feature not in continuous_features]

# Преобразуем идентифицированные объекты в объектный тип данных
df_heart[features_to_convert] = df_heart[features_to_convert].astype('object')

df_heart.dtypes
# Out:
# age           int64
# sex          object
# cp           object
# trestbps      int64
# chol          int64
# fbs          object
# restecg      object
# thalach       int64
# exang        object
# oldpeak     float64
# slope        object
# ca           object
# thal         object
# target       object
# dtype: object

# %%
df_heart.describe().T
# Out:
#           count        mean        std    min    25%    50%    75%    max
# age       303.0   54.366337   9.082101   29.0   47.5   55.0   61.0   77.0
# trestbps  303.0  131.623762  17.538143   94.0  120.0  130.0  140.0  200.0
# chol      303.0  246.264026  51.830751  126.0  211.0  240.0  274.5  564.0
# thalach   303.0  149.646865  22.905161   71.0  133.5  153.0  166.0  202.0
# oldpeak   303.0    1.039604   1.161075    0.0    0.0    0.8    1.6    6.2

# %% [markdown]
# На основе представленных статистических данных можно сделать следующие выводы:
#
# 1. Возраст (age): Средний возраст пациентов составляет около 54 лет, с минимальным возрастом 29 лет и максимальным 77 лет. Половина пациентов имеет возраст между 47.5 и 61 годами (интерквартильный размах).
#
# 2. Артериальное давление (trestbps): Среднее артериальное давление составляет около 132 мм рт. ст., с минимальным значением 94 и максимальным 200. Половина пациентов имеет давление между 120 и 140 мм рт. ст.
#
# 3. Холестерин (chol): Средний уровень холестерина составляет около 246 мг/дл, с минимальным значением 126 и максимальным 564. Половина пациентов имеет уровень холестерина между 211 и 274.5 мг/дл.
#
# 4. Максимальная частота сердечных сокращений (thalach): Средняя максимальная частота сердечных сокращений составляет около 150 ударов в минуту, с минимальным значением 71 и максимальным 202. Половина пациентов имеет максимальную частоту между 133.5 и 166 ударов в минуту.
#
# 5. Депрессия сегмента ST (oldpeak): Среднее значение депрессии ST составляет около 1.04, с минимальным значением 0 и максимальным 6.2. У половины пациентов депрессия ST находится между 0 и 1.

# %%
df_heart.describe(include='object')
# Out:
#         sex   cp  fbs  restecg  exang  slope   ca  thal  target
# count   303  303  303      303    303    303  303   303     303
# unique    2    4    2        3      2      3    5     4       2
# top       1    0    0        1      0      2    0     2       1
# freq    207  143  258      152    204    142  175   166     165

# %% [markdown]
# Анализ категориальных переменных:
#
# 1. Пол (sex): В данных присутствуют два уникальных значения, наиболее частое значение - 1 (мужской пол), которое встречается 207 раз.
#
# 2. Тип боли в груди (cp): Есть четыре уникальных типа боли в груди, наиболее распространенный тип - 0, который встречается 143 раза.
#
# 3. Уровень сахара в крови натощак (fbs): Присутствуют два уникальных значения, наиболее частое значение - 0 (уровень сахара ниже порогового значения), которое встречается 258 раз.
#
# 4. Результаты ЭКГ в покое (restecg): Есть три уникальных результата, наиболее распространенный результат - 1, который встречается 152 раза.
#
# 5. Наличие стенокардии (exang): Присутствуют два уникальных значения, наиболее частое значение - 0 (отсутствие стенокардии), которое встречается 204 раза.
#
# 6. Наклон сегмента ST (slope): Есть три уникальных типа наклона, наиболее распространенный тип - 2, который встречается 142 раза.
#
# 7. Количество крупных сосудов (ca): Присутствуют пять уникальных значений, наиболее частое значение - 0 (отсутствие крупных сосудов), которое встречается 175 раз.
#
# 8. Талассемия (thal): Есть четыре уникальных типа талассемии, наиболее распространенный тип - 2, который встречается 166 раз.
#
# 9. Целевая переменная (target): Присутствуют два уникальных значения, наиболее частое значение - 1, которое встречается 165 раз.

# %% [markdown]
# ## Задание № 2

# %% [markdown]
#  - Визуализируйте распределение количественных переменных (возраст, уровень холестерина) с помощью box plot и гистограмм.
#  - Постройте столбчатые диаграммы для анализа распределения категориальных переменных (пол, тип боли в груди).

# %% [markdown]
# Проводим однофакторный анализ объектов наборов данных на основе их типа данных:
#
# - Для непрерывных данных мы используем
# гистограммы и boxplot, чтобы получить представление о распределении каждого объекта. Это позволяет нам понять основную тенденцию, разброс и форму распределения наборов данных.
#
# - Для категориальных данных: для визуализации частоты встречаемости каждой категории используются столбчатые диаграммы. Это обеспечивает четкое представление о значимости каждой категории в рамках соответствующего объекта.
# Используя эти методы визуализации, мы получаем возможность лучше понять индивидуальные характеристики каждого объекта в наборе данных.

# %% [markdown]
# ###Одномерный анализ числовых переменных

# %%
df_continuous = df_heart[continuous_features]

fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))

# Цикл для построения гистограмм для каждого числового признака
for i, col in enumerate(df_continuous.columns):
    x = i // 3
    y = i % 3
    values, bin_edges = np.histogram(df_continuous[col],
                                     range=(np.floor(df_continuous[col].min()), np.ceil(df_continuous[col].max())))

    graph = sns.histplot(data=df_continuous, x=col, bins=bin_edges, kde=True, ax=ax[x, y],
                         edgecolor='none', color='red', alpha=0.6, line_kws={'lw': 3})
    ax[x, y].set_xlabel(col, fontsize=15)
    ax[x, y].set_ylabel('Количество', fontsize=12)
    ax[x, y].set_xticks(np.round(bin_edges, 1))
    ax[x, y].set_xticklabels(ax[x, y].get_xticks(), rotation=45)
    ax[x, y].grid(color='lightgrey')

    for j, p in enumerate(graph.patches):
        ax[x, y].annotate('{}'.format(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height() + 1),
                          ha='center', fontsize=10, fontweight="bold")

    textstr = '\n'.join((
        r'$\mu=%.2f$' % df_continuous[col].mean(),
        r'$\sigma=%.2f$' % df_continuous[col].std()
    ))
    ax[x, y].text(0.75, 0.9, textstr, transform=ax[x, y].transAxes, fontsize=12, verticalalignment='top',
                  color='white', bbox=dict(boxstyle='round', facecolor='#ff826e', edgecolor='white', pad=0.5))

ax[1,2].axis('off')
plt.suptitle('Распределение числовых переменных', fontsize=20)
plt.tight_layout()
plt.subplots_adjust(top=0.92)
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))

# Цикл для построения гистограмм для каждого непрерывного признака
for i, col in enumerate(df_continuous.columns):
    x = i // 3
    y = i % 3
    values, bin_edges = np.histogram(df_continuous[col],
                                     range=(np.floor(df_continuous[col].min()), np.ceil(df_continuous[col].max())))

    graph = sns.boxenplot(data=df_continuous, x=col, ax=ax[x, y],
                         color='blue')
    ax[x, y].set_xlabel(col, fontsize=15)
    ax[x, y].set_ylabel('Количество', fontsize=12)
    ax[x, y].set_xticks(np.round(bin_edges, 1))
    ax[x, y].set_xticklabels(ax[x, y].get_xticks(), rotation=45)
    ax[x, y].grid(color='lightgrey')


    textstr = '\n'.join((
        r'$\mu=%.2f$' % df_continuous[col].mean(),
        r'$\sigma=%.2f$' % df_continuous[col].std()
    ))
    ax[x, y].text(0.75, 0.9, textstr, transform=ax[x, y].transAxes, fontsize=12, verticalalignment='top',
                  color='white', bbox=dict(boxstyle='round', facecolor='#ff826e', edgecolor='white', pad=0.5))

ax[1,2].axis('off')
plt.suptitle('Распределение числовых переменных', fontsize=20)
plt.tight_layout()
plt.subplots_adjust(top=0.92)
plt.show()

# %% [markdown]
# 1. Первый график слева вверху показывает распределение переменной "age" (возраст). Среднее значение возраста µ = 54.37 лет, стандартное отклонение σ = 9.08 лет. Распределение относительно симметричное, с легким смещением влево, что указывает на небольшое количество молодых участников.
#
# 2. Второй график сверху посередине отображает распределение переменной "trestbps" (видимо, кровяное давление в состоянии покоя). Среднее значение составляет µ = 131.62, а стандартное отклонение — σ = 17.54. Это распределение также симметричное, соответствующее нормальному распределению.
#
# 3. Третья диаграмма в верхнем правом углу представляет переменную "chol" (холестерин). Среднее значение уровня холестерина составляет µ = 246.26, стандартное отклонение — σ = 51.83. Распределение имеет правостороннюю асимметрию, с некоторым увеличением в области высоких значений.
#
# 4. График нижний левый показывает переменную "thalach" (максимальная частота сердцебиений). Здесь среднее µ = 149.65, стандартное отклонение σ = 22.91. Распределение немного скошено влево, что указывает на меньшее количество людей с высокой максимальной частотой сердцебиений.
#
# 5. Нижний правый график иллюстрирует переменную "oldpeak", которая, вероятно, связана с уровнем депрессии сегмента ST на ЭКГ после нагрузки. Среднее значение составляет µ = 1.04, стандартное отклонение — σ = 1.16. Распределение oldpeak является сильно асимметричным с длинным правым хвостом, что указывает на значительное количество низких значений и сравнительно малое количество высоких значений.

# %% [markdown]
# ###Одномерный анализ категориальных признаков

# %%
categorical_features = df_heart.columns.difference(continuous_features)
df_categorical = df_heart[categorical_features]

fig, ax = plt.subplots(nrows=5, ncols=2, figsize=(15, 18))

# Цикл для построения столбчатых диаграмм для каждого категориального объекта в макете 4х2
for i, col in enumerate(categorical_features):
    row = i // 2
    col_idx = i % 2

    # Вычисление процентных значений частоты
    value_counts = df_heart[col].value_counts(normalize=True).mul(100).sort_values()

    # Построение столбчатой диаграммы
    value_counts.plot(kind='barh', ax=ax[row, col_idx], width=0.8, color='blue')

    # Добавим процентные значения частоты к столбцам
    for index, value in enumerate(value_counts):
        ax[row, col_idx].text(value, index, str(round(value, 1)) + '%',
                              fontsize=15, weight='bold', va='center')

    ax[row, col_idx].set_xlim([0, 95])
    ax[row, col_idx].set_xlabel('Частота в процентах', fontsize=12)
    ax[row, col_idx].set_title(f'{col}', fontsize=20)

ax[4,1].axis('off')
plt.suptitle('Распределение категориальных признаков', fontsize=22)
plt.tight_layout()
plt.subplots_adjust(top=0.95)
plt.show()

# %% [markdown]
# - В верхнем левом углу график для признака `ca`: категория "0" встречается в 57,8% случаев, "1" — в 21,5%, "2" — в 12,5%, "3" — в 6,6% и "4" — в 1,7% случаев.
# - В верхнем правом углу график для признака `cp`: тип "0" составляет 47,2%, "1" — 28,7%, "2" — 16,5%, и "3" — 7,6%.
# - В центре слева график для признака `exang`: "0" встречается в 67,3% случаев, и "1" — в 32,7%.
# - В центре справа график для признака `fbs`: "0" составляет 85,1%, и "1" — 14,9%.
# - В левой нижней части изображения график для признака `restecg`: категория "0" — 50,2%, "1" — 48,5%, и "2" — 1,3%.
# - В центре снизу график для признака `sex`: "0" соответствует 31,7% и "1" — 68,3%.
# - В нижнем правом углу график для признака `slope`: категория "2" встречается в 46,9% случаев, "1" — в 46,2%, и "0" — в 6,9%.
# - В правом нижнем углу график для признака `thal`: "2" составляет 54,8%, "3" — 38,6%, "1" — в 5,9%, и "0" — 0,7%.
# - В нижней части посередине расположен график для признака `target`: категория "1" составляет 54,5% и "0" — 45,5%.

# %% [markdown]
# ##Задание 3

# %% [markdown]
# Проведите двумерный анализ объектов набора данных в зависимости от целевой переменной (target).
#    - Для непрерывных переменных (age, trestbps, chol, thalach, oldpeak) постройте гистограммы, отображающие среднее значение каждого объекта для разных целевых классов, и графики KDE, показывающие распределение каждого объекта по целевым классам.
#    - Для категориальных переменных (sex, cp, fbs, restecg, exang, slope, ca, thal) создайте гистограммы со 100-процентным распределением, демонстрирующие долю каждой категории в целевых классах.

# %% [markdown]
# ###Двумерный анализ количественных признаков

# %%
sns.set_palette(['#ff826e', 'red'])


fig, ax = plt.subplots(len(continuous_features), 2, figsize=(15,15), gridspec_kw={'width_ratios': [1, 2]})

# Цикл для каждого численного признака для создания линейчатых диаграмм и графиков kde
for i, col in enumerate(continuous_features):
    # Гистограмма, показывающая среднее значение признака для каждой целевой категории
    graph = sns.barplot(data=df_heart, x="target", y=col, ax=ax[i,0])

    # График KDE, показывающий распределение признака для каждой целевой категории
    sns.kdeplot(data=df_heart[df_heart["target"]==0], x=col, fill=True, linewidth=2, ax=ax[i,1], label='0',
                color = 'blue')
    sns.kdeplot(data=df_heart[df_heart["target"]==1], x=col, fill=True, linewidth=2, ax=ax[i,1], label='1')
    ax[i,1].set_yticks([])
    ax[i,1].legend(title='Heart Disease', loc='upper right')

    # средние значения в гистограмму
    for cont in graph.containers:
        graph.bar_label(cont, fmt='         %.3g')


plt.suptitle('Количественные признаки в сравнении с целевым распределением', fontsize=22)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Двумерный анализ для категориальных признаков

# %%
categorical_features = [feature for feature in categorical_features if feature != 'target']
fig, ax = plt.subplots(nrows=2, ncols=4, figsize=(15,10))

for i,col in enumerate(categorical_features):

    # Создайте перекрестную таблицу для каждой категории объекта
    cross_tab = pd.crosstab(index=df_heart[col], columns=df_heart['target'])

    # Использование аргумента normalize=True дает нам соотношение данных по индексу
    cross_tab_prop = pd.crosstab(index=df_heart[col], columns=df_heart['target'], normalize='index')

    # Определение цветовой карты
    cmp = ListedColormap(['skyblue', '#ff826e'])

    # Построение многослойных столбчатых диаграмм
    x, y = i//4, i%4
    cross_tab_prop.plot(kind='bar', ax=ax[x,y], stacked=True, width=0.8, colormap=cmp,
                        legend=False, ylabel='Пропорция', sharey=True)

    # Добавим пропорции и количество отдельных бинов к нашему графику
    for idx, val in enumerate([*cross_tab.index.values]):
        for (proportion, count, y_location) in zip(cross_tab_prop.loc[val],cross_tab.loc[val],cross_tab_prop.loc[val].cumsum()):
            ax[x,y].text(x=idx-0.3, y=(y_location-proportion)+(proportion/2)-0.03,
                         s = f'    {count}\n({np.round(proportion * 100, 1)}%)',
                         color = "black", fontsize=9, fontweight="bold")


    ax[x,y].legend(title='target', loc=(0.7,0.9), fontsize=8, ncol=2)
    ax[x,y].set_ylim([0,1.12])
    ax[x,y].set_xticklabels(ax[x,y].get_xticklabels(), rotation=0)


plt.suptitle('Категориальные признаки в сравнении с целевыми значением столбчатые диаграммы', fontsize=22)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##Задание 4

# %% [markdown]
# Проанализируйте результаты проведенного анализа и сделайте выводы:
#    - Определите, какие переменные имеют наибольшее влияние на наличие сердечных заболеваний.
#    - Выявите потенциальные закономерности и взаимосвязи между переменными и целевой переменной.
#    - Оцените качество и полноту предоставленных данных, а также возможные ограничения анализа. Какие переменные показывают наибольшую разницу в распределении между группами пациентов с сердечными заболеваниями и без них?

# %% [markdown]
# ###Анализ числовых признаков

# %% [markdown]
# Слева направо и сверху вниз представлены следующие признаки:
# 1. Age (возраст) - наблюдается перекрытие между двумя классами, но кажется, что люди с заболеваниями сердца (1) в среднем младше.
# 2. Trestbps (величина артериального давления в состоянии покоя) - распределения для людей с и без сердечных заболеваний перекрываются.
# 3. Chol (уровень холестерина) - распределение уровня холестерина также показывает перекрытие между двумя классами.
# 4. Thalach (максимальный сердечный ритм достигнутый во время теста) - люди с сердечными заболеваниями, похоже, имеют тенденцию достигать более высокого максимального сердечного ритма.
# 5. Oldpeak (депрессия ST сегмента, вызванная упражнениями относительно отдыха) - распределения показывают, что наблюдается более высокое значение oldpeak у людей с заболеваниями сердца, чем у тех, кто здоров.

# %% [markdown]
# ###Анализ категориальных признаков

# %% [markdown]
# Например, если мы рассмотрим первую диаграмму для признака "ca":
# - Значение 0 для признака "ca" имеет 175 записей, из которых 130 (74.3%) соответствуют цели 0, а 45 (25.7%) — цели 1.
# - Значение 1 для признака "ca" имеет 44 записей, из которых 31 (81.6%) соответствуют цели 0, а 13 (18.4%) — цели 1

# %% [markdown]
# ###Обобщение

# %% [markdown]
# На основе проведенного анализа можно сделать следующие выводы:
#
# 1. Переменные, которые потенциально имеют наибольшее влияние на наличие сердечных заболеваний:
#    - Тип боли в груди (cp): распределение типов боли в груди значительно различается между группами пациентов с сердечными заболеваниями и без них.
#    - Максимальная частота сердечных сокращений (thalach): пациенты с сердечными заболеваниями имеют более низкую максимальную частоту сердечных сокращений по сравнению с пациентами без заболеваний.
#    - Депрессия сегмента ST (oldpeak): у пациентов с сердечными заболеваниями наблюдаются более высокие значения депрессии ST.
#
# 2. Потенциальные закономерности и взаимосвязи:
#    - Пол (sex): мужчины более склонны к сердечным заболеваниям, чем женщины.
#    - Возраст (age): риск сердечных заболеваний увеличивается с возрастом.
#    - Холестерин (chol): пациенты с сердечными заболеваниями имеют более высокий уровень холестерина.
#
# 3. Качество и полнота данных:
#    - Данные не содержат пропущенных значений, что является положительным фактором для анализа.
#    - Однако, данные могут быть ограничены в плане разнообразия выборки (например, географического охвата или демографических характеристик пациентов).
#    - Дополнительные переменные, такие как индекс массы тела, курение или семейная история сердечных заболеваний, могли бы улучшить анализ.

# %% [markdown]
# Основываясь на представленных данных и описании признаков, можно сделать следующие выводы:
#
# 1. Пол (sex): Мужчины (значение 1) составляют большую часть выборки (68,3%) по сравнению с женщинами (31,7%). При этом среди пациентов с сердечными заболеваниями (target=1) доля мужчин выше, чем среди здоровых пациентов.
#
# 2. Тип боли в груди (cp): Наиболее распространенным типом боли является типичная стенокардия (значение 0), за которой следуют атипичная стенокардия (значение 1) и боль, не связанная со стенокардией (значение 2). Среди пациентов с сердечными заболеваниями наблюдается более высокая доля атипичной стенокардии и боли, не связанной со стенокардией.
#
# 3. Результаты электрокардиографии в состоянии покоя (restecg): Распределение значений restecg примерно одинаково для здоровых пациентов и пациентов с сердечными заболеваниями, что указывает на то, что этот признак может быть менее информативным для диагностики.
#
# 4. Стенокардия, вызванная физической нагрузкой (exang): Большинство пациентов (67,3%) не испытывают стенокардии при физической нагрузке. Однако среди пациентов с сердечными заболеваниями доля тех, кто испытывает стенокардию, значительно выше.
#
# 5. Количество крупных сосудов (ca): Большинство пациентов (57,8%) имеют значение ca=0, что указывает на отсутствие окрашенных крупных сосудов при рентгеноскопии. Среди пациентов с сердечными заболеваниями наблюдается более высокая доля случаев с ca>0.
#
# 6. Результат нагрузочного теста на таллий (thal): Наиболее распространенным результатом является обратимый дефект (значение 2), за которым следует "не описано" (значение 3). Среди пациентов с сердечными заболеваниями наблюдается более высокая доля случаев с обратимым дефектом.

# %% [markdown]
# ##Домашнее задание

# %% [markdown]
# Задание
# Исследование данных о качестве вина ( [Wine Quality Dataset](https://archive.ics.uci.edu/static/public/186/wine+quality.zip)):
# Проведите первичный анализ данных: изучите типы переменных, наличие пропусков, статистические характеристики.
#  - Визуализируйте распределение количественных переменных с помощью гистограмм и box plot.
#  - Постройте столбчатые диаграммы для анализа распределения категориальных переменных .
#  - Сделайте выводы о качестве данных и потенциальных взаимосвязях.
